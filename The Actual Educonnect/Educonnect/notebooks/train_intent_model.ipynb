# %% [markdown]
# # Training a Custom Intent Classification Model
#
# This notebook demostrates fine-tuning a HuggingFace Transformer on a dataset of user messages and intent labels. You can replace the sample dataset with your own CSV file containing `message,label` pairs.

# %%
# install required packages (only run once or if you get import errors)
# !pip install transformers datasets torch scikit-learn evaluate

# Imports: os and pandas for file handling & data, datasets for making HF dataset,
# evaluate for metrics, transformers for the model/training, torch for tensors
import os
import pandas as pd
from datasets import Dataset
import evaluate
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
import torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in c:\users\hp pc\appdata\roaming\python\python312\site-packages (5.2.0)
# Requirement already satisfied: datasets in c:\users\hp pc\appdata\roaming\python\python312\site-packages (4.6.1)
# Requirement already satisfied: torch in c:\users\hp pc\appdata\roaming\python\python312\site-packages (2.10.0)
# Requirement already satisfied: scikit-learn in c:\users\hp pc\appdata\roaming\python\python312\site-packages (1.6.1)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from transformers) (1.5.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from transformers) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typer in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.12.2)
# Requirement already satisfied: anyio in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: xxhash in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from datasets) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from torch) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from torch) (72.2.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from requests>=2.32.2->datasets) (2.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: click>=8.2.1 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp pc\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.1.2)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load dataset from CSV (you can replace the path with your own file)
# the CSV should contain two columns: `message` and `label`.
# example path below; uncomment the pd.read_csv line when you have a real file.

csv_path = os.path.join(os.path.dirname(os.getcwd()), 'data', 'intents.csv')
# df = pd.read_csv(csv_path)

# For demonstration create a small dummy dataframe until you supply real data
# (this allows the rest of the notebook to execute without an actual file)
df = pd.DataFrame({
    'message': ['how do i log in?', 'where are the quizzes?', 'tell me a joke'],
    'label': ['login', 'quizzes', 'misc']
})


df.head()

# %%
# Convert pandas dataframe to HuggingFace Dataset and tokenize
# create mapping dictionaries between labels and integer IDs
label_list = df['label'].unique().tolist()
label2id = {l:i for i,l in enumerate(label_list)}
id2label = {i:l for l,i in label2id.items()}

df['label_id'] = df['label'].map(label2id)  # add numeric label column

# build HF dataset containing only message and label_id columns
hf_dataset = Dataset.from_pandas(df[['message','label_id']])

# load tokenizer from pretrained model (same base model we'll fine-tune)
tokenizer = AutoTokenizer.from_pretrained('distilbert-base-uncased')

def preprocess(examples):
    # tokenise each text, pad/truncate to fixed length
    return tokenizer(examples['message'], truncation=True, padding='max_length', max_length=128)

hf_dataset = hf_dataset.map(preprocess, batched=True)



# split into train/test setshf_dataset
hf_dataset = hf_dataset.train_test_split(test_size=0.2)

# %%
# Initialize the model and training configuration
# number of distinct intent labels determines the classifier size
num_labels = len(label_list)
model = AutoModelForSequenceClassification.from_pretrained(
    'distilbert-base-uncased',
    num_labels=num_labels,
    id2label=id2label,
    label2id=label2id
)

# training arguments control learning process and output location
training_args = TrainingArguments(
    output_dir='./models/intent',        # where checkpoints will be saved
    evaluation_strategy='epoch',         # evaluate at end of each epoch
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    save_total_limit=2,                  # keep last two checkpoints
)

# set up evaluation metric using evaluate library
metric = evaluate.load('accuracy')

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = logits.argmax(axis=-1)
    return metric.compute(predictions=predictions, references=labels)

# build trainer object to handle training loop
trainer = Trainer(

    model=model,

    args=training_args,trainer  # display trainer configuration

    train_dataset=hf_dataset['train'],

    eval_dataset=hf_dataset['test'],)
    compute_metrics=compute_metrics,

# %%
# Train the model (this may take several minutes depending on data size and hardware)
trainer.train()

# After training, save the fine-tuned model and tokenizer for later inference
trainer.save_model('./models/intent')
tokenizer.save_pretrained('./models/intent')

# %%
# Example inference on a new message using the trained model

def predict(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=128)
    outputs = model(**inputs)
    pred = outputs.logits.argmax(dim=-1).item()
    return id2label[pred]

# try a couple of test sentences to see the predicted intent
print(predict("how do i log in?"))
print(predict("show me resources"))
